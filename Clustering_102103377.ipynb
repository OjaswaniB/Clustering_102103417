# %%
# !pip install pycaret
# Out:
# Requirement already satisfied: pycaret in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (3.2.0)
# Requirement already satisfied: category-encoders>=2.4.0 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from pycaret) (2.6.3)
# Requirement already satisfied: cloudpickle in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from pycaret) (3.0.0)
# Requirement already satisfied: deprecation>=2.1.0 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from pycaret) (2.1.0)
# Requirement already satisfied: imbalanced-learn>=0.8.1 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from pycaret) (0.12.0)
# Requirement already satisfied: importlib-metadata>=4.12.0 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from pycaret) (6.8.0)
# Requirement already satisfied: ipython>=5.5.0 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from pycaret) (8.12.0)
# Requirement already satisfied: ipywidgets>=7.6.5 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from pycaret) (7.7.2)
# Requirement already satisfied: jinja2>=1.2 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from pycaret) (3.1.2)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from pycaret) (1.3.2)
# Requirement already satisfied: kaleido>=0.2.1 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from pycaret) (0.2.1)
# Requirement already satisfied: lightgbm>=3.0.0 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from pycaret) (4.3.0)
# Requirement already satisfied: markupsafe>=2.0.1 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from pycaret) (2.1.1)
# Requirement already satisfied: matplotlib<=3.6,>=3.3.0 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from pycaret) (3.6.0)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from pycaret) (5.7.0)
# Requirement already satisfied: numba>=0.55.0 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from pycaret) (0.59.0)
# Requirement already satisfied: numpy<1.27,>=1.21 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from pycaret) (1.25.1)
# Requirement already satisfied: pandas<2.0.0,>=1.3.0 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from pycaret) (1.5.3)
# Requirement already satisfied: plotly-resampler>=0.8.3.1 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from pycaret) (0.9.2)
# Requirement already satisfied: plotly>=5.0.0 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from pycaret) (5.18.0)
# Requirement already satisfied: pmdarima!=1.8.1,<3.0.0,>=1.8.0 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from pycaret) (2.0.4)
# Requirement already satisfied: psutil>=5.9.0 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from pycaret) (5.9.0)
# Requirement already satisfied: pyod>=1.0.8 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from pycaret) (1.1.3)
# Requirement already satisfied: requests>=2.27.1 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from pycaret) (2.29.0)
# Requirement already satisfied: schemdraw==0.15 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from pycaret) (0.15)
# Requirement already satisfied: scikit-learn<1.3.0,>=1.0 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from pycaret) (1.2.2)
# Requirement already satisfied: scikit-plot>=0.3.7 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from pycaret) (0.3.7)
# Requirement already satisfied: scipy~=1.10.1 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from pycaret) (1.10.1)
# Requirement already satisfied: sktime!=0.17.1,!=0.17.2,!=0.18.0,<0.22.0,>=0.16.1 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from pycaret) (0.21.1)
# Requirement already satisfied: statsmodels>=0.12.1 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from pycaret) (0.14.1)
# Requirement already satisfied: tbats>=1.1.3 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from pycaret) (1.1.3)
# Requirement already satisfied: tqdm>=4.62.0 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from pycaret) (4.65.0)
# Requirement already satisfied: xxhash in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from pycaret) (3.4.1)
# Requirement already satisfied: yellowbrick>=1.4 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from pycaret) (1.5)
# Requirement already satisfied: patsy>=0.5.1 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from category-encoders>=2.4.0->pycaret) (0.5.6)
# Requirement already satisfied: packaging in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from deprecation>=2.1.0->pycaret) (23.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from imbalanced-learn>=0.8.1->pycaret) (3.2.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from importlib-metadata>=4.12.0->pycaret) (3.17.0)
# Requirement already satisfied: backcall in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from ipython>=5.5.0->pycaret) (0.2.0)
# Requirement already satisfied: decorator in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from ipython>=5.5.0->pycaret) (4.4.2)
# Requirement already satisfied: jedi>=0.16 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from ipython>=5.5.0->pycaret) (0.18.1)
# Requirement already satisfied: matplotlib-inline in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from ipython>=5.5.0->pycaret) (0.1.6)
# Requirement already satisfied: pickleshare in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from ipython>=5.5.0->pycaret) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from ipython>=5.5.0->pycaret) (3.0.36)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from ipython>=5.5.0->pycaret) (2.15.1)
# Requirement already satisfied: stack-data in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from ipython>=5.5.0->pycaret) (0.2.0)
# Requirement already satisfied: traitlets>=5 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from ipython>=5.5.0->pycaret) (5.7.1)
# Requirement already satisfied: colorama in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from ipython>=5.5.0->pycaret) (0.4.6)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from ipywidgets>=7.6.5->pycaret) (6.19.2)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from ipywidgets>=7.6.5->pycaret) (0.2.0)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from ipywidgets>=7.6.5->pycaret) (3.6.6)
# Requirement already satisfied: jupyterlab-widgets<3,>=1.0.0 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from ipywidgets>=7.6.5->pycaret) (1.1.7)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from matplotlib<=3.6,>=3.3.0->pycaret) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from matplotlib<=3.6,>=3.3.0->pycaret) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from matplotlib<=3.6,>=3.3.0->pycaret) (4.41.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from matplotlib<=3.6,>=3.3.0->pycaret) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from matplotlib<=3.6,>=3.3.0->pycaret) (10.0.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from matplotlib<=3.6,>=3.3.0->pycaret) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from matplotlib<=3.6,>=3.3.0->pycaret) (2.8.2)
# Requirement already satisfied: fastjsonschema in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from nbformat>=4.2.0->pycaret) (2.16.2)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from nbformat>=4.2.0->pycaret) (4.17.3)
# Requirement already satisfied: jupyter-core in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from nbformat>=4.2.0->pycaret) (5.3.0)
# Requirement already satisfied: llvmlite<0.43,>=0.42.0dev0 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from numba>=0.55.0->pycaret) (0.42.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from pandas<2.0.0,>=1.3.0->pycaret) (2022.7)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from plotly>=5.0.0->pycaret) (8.2.3)
# Requirement already satisfied: dash>=2.9.0 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from plotly-resampler>=0.8.3.1->pycaret) (2.15.0)
# Requirement already satisfied: orjson<4.0.0,>=3.8.0 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from plotly-resampler>=0.8.3.1->pycaret) (3.9.2)
# Requirement already satisfied: tsdownsample==0.1.2 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from plotly-resampler>=0.8.3.1->pycaret) (0.1.2)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from pmdarima!=1.8.1,<3.0.0,>=1.8.0->pycaret) (3.0.8)
# Requirement already satisfied: urllib3 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from pmdarima!=1.8.1,<3.0.0,>=1.8.0->pycaret) (1.26.16)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from pmdarima!=1.8.1,<3.0.0,>=1.8.0->pycaret) (67.8.0)
# Requirement already satisfied: six in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from pyod>=1.0.8->pycaret) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from requests>=2.27.1->pycaret) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from requests>=2.27.1->pycaret) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from requests>=2.27.1->pycaret) (2023.5.7)
# Requirement already satisfied: deprecated>=1.2.13 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from sktime!=0.17.1,!=0.17.2,!=0.18.0,<0.22.0,>=0.16.1->pycaret) (1.2.14)
# Requirement already satisfied: scikit-base<0.6.0 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from sktime!=0.17.1,!=0.17.2,!=0.18.0,<0.22.0,>=0.16.1->pycaret) (0.5.2)
# Requirement already satisfied: Flask<3.1,>=1.0.4 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (3.0.0)
# Requirement already satisfied: Werkzeug<3.1 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (3.0.1)
# Requirement already satisfied: dash-html-components==2.0.0 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (2.0.0)
# Requirement already satisfied: dash-core-components==2.0.0 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (2.0.0)
# Requirement already satisfied: dash-table==5.0.0 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (5.0.0)
# Requirement already satisfied: typing-extensions>=4.1.1 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (4.6.3)
# Requirement already satisfied: retrying in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (1.3.4)
# Requirement already satisfied: nest-asyncio in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (1.5.6)
# Requirement already satisfied: wrapt<2,>=1.10 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from deprecated>=1.2.13->sktime!=0.17.1,!=0.17.2,!=0.18.0,<0.22.0,>=0.16.1->pycaret) (1.16.0)
# Requirement already satisfied: comm>=0.1.1 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (0.1.2)
# Requirement already satisfied: debugpy>=1.0 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (1.5.1)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (8.1.0)
# Requirement already satisfied: pyzmq>=17 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (25.1.0)
# Requirement already satisfied: tornado>=6.1 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (6.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from jedi>=0.16->ipython>=5.5.0->pycaret) (0.8.3)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (22.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (0.18.0)
# Requirement already satisfied: wcwidth in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=5.5.0->pycaret) (0.2.5)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (6.5.4)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from jupyter-core->nbformat>=4.2.0->pycaret) (2.5.2)
# Requirement already satisfied: pywin32>=300 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from jupyter-core->nbformat>=4.2.0->pycaret) (305.1)
# Requirement already satisfied: executing in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from stack-data->ipython>=5.5.0->pycaret) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from stack-data->ipython>=5.5.0->pycaret) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from stack-data->ipython>=5.5.0->pycaret) (0.2.2)
# Requirement already satisfied: itsdangerous>=2.1.2 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from Flask<3.1,>=1.0.4->dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (2.1.2)
# Requirement already satisfied: click>=8.1.3 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from Flask<3.1,>=1.0.4->dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (8.1.6)
# Requirement already satisfied: blinker>=1.6.2 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from Flask<3.1,>=1.0.4->dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (1.7.0)
# Requirement already satisfied: argon2-cffi in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (21.3.0)
# Requirement already satisfied: nbconvert>=5 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (6.5.4)
# Requirement already satisfied: Send2Trash>=1.8.0 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (1.8.0)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (0.17.1)
# Requirement already satisfied: prometheus-client in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (0.14.1)
# Requirement already satisfied: nbclassic>=0.4.7 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (0.5.5)
# Requirement already satisfied: jupyter-server>=1.8 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (2.5.0)
# Requirement already satisfied: notebook-shim>=0.1.0 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (0.2.2)
# Requirement already satisfied: lxml in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (4.9.2)
# Requirement already satisfied: beautifulsoup4 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (4.12.2)
# Requirement already satisfied: bleach in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (4.1.0)
# Requirement already satisfied: defusedxml in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (0.7.1)
# Requirement already satisfied: entrypoints>=0.2.2 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (0.4)
# Requirement already satisfied: jupyterlab-pygments in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (0.1.2)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (0.8.4)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (0.5.13)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (1.5.0)
# Requirement already satisfied: tinycss2 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (1.2.1)
# Requirement already satisfied: pywinpty>=1.1.0 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from terminado>=0.8.3->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (2.0.10)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (21.2.0)
# Requirement already satisfied: anyio>=3.1.0 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (3.5.0)
# Requirement already satisfied: jupyter-events>=0.4.0 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (0.6.3)
# Requirement already satisfied: jupyter-server-terminals in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (0.4.4)
# Requirement already satisfied: websocket-client in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (0.58.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (1.15.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (2.4)
# Requirement already satisfied: webencodings in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from bleach->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (0.5.1)
# Requirement already satisfied: sniffio>=1.1 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from anyio>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (1.2.0)
# Requirement already satisfied: pycparser in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (2.21)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from jupyter-events>=0.4.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (2.0.7)
# Requirement already satisfied: pyyaml>=5.3 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from jupyter-events>=0.4.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (6.0)
# Requirement already satisfied: rfc3339-validator in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from jupyter-events>=0.4.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from jupyter-events>=0.4.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (0.1.1)
# Requirement already satisfied: fqdn in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (1.5.1)
# Requirement already satisfied: isoduration in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (2.4)
# Requirement already satisfied: uri-template in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (1.3.0)
# Requirement already satisfied: webcolors>=1.11 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (1.13)
# Requirement already satisfied: arrow>=0.15.0 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from isoduration->jsonschema>=2.6->nbformat>=4.2.0->pycaret) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from arrow>=0.15.0->isoduration->jsonschema>=2.6->nbformat>=4.2.0->pycaret) (2.8.19.14)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from pycaret.utils import version
version()
# Out:
# '3.2.0'

# %%
# !pip install pycaret
# Out:
# Requirement already satisfied: pycaret in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (3.2.0)
# Requirement already satisfied: category-encoders>=2.4.0 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from pycaret) (2.6.3)
# Requirement already satisfied: cloudpickle in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from pycaret) (3.0.0)
# Requirement already satisfied: deprecation>=2.1.0 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from pycaret) (2.1.0)
# Requirement already satisfied: imbalanced-learn>=0.8.1 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from pycaret) (0.12.0)
# Requirement already satisfied: importlib-metadata>=4.12.0 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from pycaret) (6.8.0)
# Requirement already satisfied: ipython>=5.5.0 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from pycaret) (8.12.0)
# Requirement already satisfied: ipywidgets>=7.6.5 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from pycaret) (7.7.2)
# Requirement already satisfied: jinja2>=1.2 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from pycaret) (3.1.2)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from pycaret) (1.3.2)
# Requirement already satisfied: kaleido>=0.2.1 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from pycaret) (0.2.1)
# Requirement already satisfied: lightgbm>=3.0.0 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from pycaret) (4.3.0)
# Requirement already satisfied: markupsafe>=2.0.1 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from pycaret) (2.1.1)
# Requirement already satisfied: matplotlib<=3.6,>=3.3.0 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from pycaret) (3.6.0)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from pycaret) (5.7.0)
# Requirement already satisfied: numba>=0.55.0 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from pycaret) (0.59.0)
# Requirement already satisfied: numpy<1.27,>=1.21 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from pycaret) (1.25.1)
# Requirement already satisfied: pandas<2.0.0,>=1.3.0 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from pycaret) (1.5.3)
# Requirement already satisfied: plotly-resampler>=0.8.3.1 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from pycaret) (0.9.2)
# Requirement already satisfied: plotly>=5.0.0 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from pycaret) (5.18.0)
# Requirement already satisfied: pmdarima!=1.8.1,<3.0.0,>=1.8.0 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from pycaret) (2.0.4)
# Requirement already satisfied: psutil>=5.9.0 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from pycaret) (5.9.0)
# Requirement already satisfied: pyod>=1.0.8 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from pycaret) (1.1.3)
# Requirement already satisfied: requests>=2.27.1 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from pycaret) (2.29.0)
# Requirement already satisfied: schemdraw==0.15 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from pycaret) (0.15)
# Requirement already satisfied: scikit-learn<1.3.0,>=1.0 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from pycaret) (1.2.2)
# Requirement already satisfied: scikit-plot>=0.3.7 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from pycaret) (0.3.7)
# Requirement already satisfied: scipy~=1.10.1 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from pycaret) (1.10.1)
# Requirement already satisfied: sktime!=0.17.1,!=0.17.2,!=0.18.0,<0.22.0,>=0.16.1 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from pycaret) (0.21.1)
# Requirement already satisfied: statsmodels>=0.12.1 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from pycaret) (0.14.1)
# Requirement already satisfied: tbats>=1.1.3 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from pycaret) (1.1.3)
# Requirement already satisfied: tqdm>=4.62.0 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from pycaret) (4.65.0)
# Requirement already satisfied: xxhash in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from pycaret) (3.4.1)
# Requirement already satisfied: yellowbrick>=1.4 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from pycaret) (1.5)
# Requirement already satisfied: patsy>=0.5.1 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from category-encoders>=2.4.0->pycaret) (0.5.6)
# Requirement already satisfied: packaging in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from deprecation>=2.1.0->pycaret) (23.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from imbalanced-learn>=0.8.1->pycaret) (3.2.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from importlib-metadata>=4.12.0->pycaret) (3.17.0)
# Requirement already satisfied: backcall in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from ipython>=5.5.0->pycaret) (0.2.0)
# Requirement already satisfied: decorator in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from ipython>=5.5.0->pycaret) (4.4.2)
# Requirement already satisfied: jedi>=0.16 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from ipython>=5.5.0->pycaret) (0.18.1)
# Requirement already satisfied: matplotlib-inline in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from ipython>=5.5.0->pycaret) (0.1.6)
# Requirement already satisfied: pickleshare in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from ipython>=5.5.0->pycaret) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from ipython>=5.5.0->pycaret) (3.0.36)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from ipython>=5.5.0->pycaret) (2.15.1)
# Requirement already satisfied: stack-data in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from ipython>=5.5.0->pycaret) (0.2.0)
# Requirement already satisfied: traitlets>=5 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from ipython>=5.5.0->pycaret) (5.7.1)
# Requirement already satisfied: colorama in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from ipython>=5.5.0->pycaret) (0.4.6)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from ipywidgets>=7.6.5->pycaret) (6.19.2)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from ipywidgets>=7.6.5->pycaret) (0.2.0)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from ipywidgets>=7.6.5->pycaret) (3.6.6)
# Requirement already satisfied: jupyterlab-widgets<3,>=1.0.0 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from ipywidgets>=7.6.5->pycaret) (1.1.7)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from matplotlib<=3.6,>=3.3.0->pycaret) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from matplotlib<=3.6,>=3.3.0->pycaret) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from matplotlib<=3.6,>=3.3.0->pycaret) (4.41.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from matplotlib<=3.6,>=3.3.0->pycaret) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from matplotlib<=3.6,>=3.3.0->pycaret) (10.0.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from matplotlib<=3.6,>=3.3.0->pycaret) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from matplotlib<=3.6,>=3.3.0->pycaret) (2.8.2)
# Requirement already satisfied: fastjsonschema in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from nbformat>=4.2.0->pycaret) (2.16.2)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from nbformat>=4.2.0->pycaret) (4.17.3)
# Requirement already satisfied: jupyter-core in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from nbformat>=4.2.0->pycaret) (5.3.0)
# Requirement already satisfied: llvmlite<0.43,>=0.42.0dev0 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from numba>=0.55.0->pycaret) (0.42.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from pandas<2.0.0,>=1.3.0->pycaret) (2022.7)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from plotly>=5.0.0->pycaret) (8.2.3)
# Requirement already satisfied: dash>=2.9.0 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from plotly-resampler>=0.8.3.1->pycaret) (2.15.0)
# Requirement already satisfied: orjson<4.0.0,>=3.8.0 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from plotly-resampler>=0.8.3.1->pycaret) (3.9.2)
# Requirement already satisfied: tsdownsample==0.1.2 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from plotly-resampler>=0.8.3.1->pycaret) (0.1.2)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from pmdarima!=1.8.1,<3.0.0,>=1.8.0->pycaret) (3.0.8)
# Requirement already satisfied: urllib3 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from pmdarima!=1.8.1,<3.0.0,>=1.8.0->pycaret) (1.26.16)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from pmdarima!=1.8.1,<3.0.0,>=1.8.0->pycaret) (67.8.0)
# Requirement already satisfied: six in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from pyod>=1.0.8->pycaret) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from requests>=2.27.1->pycaret) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from requests>=2.27.1->pycaret) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from requests>=2.27.1->pycaret) (2023.5.7)
# Requirement already satisfied: deprecated>=1.2.13 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from sktime!=0.17.1,!=0.17.2,!=0.18.0,<0.22.0,>=0.16.1->pycaret) (1.2.14)
# Requirement already satisfied: scikit-base<0.6.0 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from sktime!=0.17.1,!=0.17.2,!=0.18.0,<0.22.0,>=0.16.1->pycaret) (0.5.2)
# Requirement already satisfied: Flask<3.1,>=1.0.4 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (3.0.0)
# Requirement already satisfied: Werkzeug<3.1 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (3.0.1)
# Requirement already satisfied: dash-html-components==2.0.0 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (2.0.0)
# Requirement already satisfied: dash-core-components==2.0.0 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (2.0.0)
# Requirement already satisfied: dash-table==5.0.0 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (5.0.0)
# Requirement already satisfied: typing-extensions>=4.1.1 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (4.6.3)
# Requirement already satisfied: retrying in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (1.3.4)
# Requirement already satisfied: nest-asyncio in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (1.5.6)
# Requirement already satisfied: wrapt<2,>=1.10 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from deprecated>=1.2.13->sktime!=0.17.1,!=0.17.2,!=0.18.0,<0.22.0,>=0.16.1->pycaret) (1.16.0)
# Requirement already satisfied: comm>=0.1.1 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (0.1.2)
# Requirement already satisfied: debugpy>=1.0 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (1.5.1)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (8.1.0)
# Requirement already satisfied: pyzmq>=17 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (25.1.0)
# Requirement already satisfied: tornado>=6.1 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.6.5->pycaret) (6.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from jedi>=0.16->ipython>=5.5.0->pycaret) (0.8.3)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (22.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (0.18.0)
# Requirement already satisfied: wcwidth in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=5.5.0->pycaret) (0.2.5)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (6.5.4)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from jupyter-core->nbformat>=4.2.0->pycaret) (2.5.2)
# Requirement already satisfied: pywin32>=300 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from jupyter-core->nbformat>=4.2.0->pycaret) (305.1)
# Requirement already satisfied: executing in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from stack-data->ipython>=5.5.0->pycaret) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from stack-data->ipython>=5.5.0->pycaret) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from stack-data->ipython>=5.5.0->pycaret) (0.2.2)
# Requirement already satisfied: itsdangerous>=2.1.2 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from Flask<3.1,>=1.0.4->dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (2.1.2)
# Requirement already satisfied: click>=8.1.3 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from Flask<3.1,>=1.0.4->dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (8.1.6)
# Requirement already satisfied: blinker>=1.6.2 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from Flask<3.1,>=1.0.4->dash>=2.9.0->plotly-resampler>=0.8.3.1->pycaret) (1.7.0)
# Requirement already satisfied: argon2-cffi in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (21.3.0)
# Requirement already satisfied: nbconvert>=5 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (6.5.4)
# Requirement already satisfied: Send2Trash>=1.8.0 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (1.8.0)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (0.17.1)
# Requirement already satisfied: prometheus-client in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (0.14.1)
# Requirement already satisfied: nbclassic>=0.4.7 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (0.5.5)
# Requirement already satisfied: jupyter-server>=1.8 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (2.5.0)
# Requirement already satisfied: notebook-shim>=0.1.0 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (0.2.2)
# Requirement already satisfied: lxml in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (4.9.2)
# Requirement already satisfied: beautifulsoup4 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (4.12.2)
# Requirement already satisfied: bleach in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (4.1.0)
# Requirement already satisfied: defusedxml in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (0.7.1)
# Requirement already satisfied: entrypoints>=0.2.2 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (0.4)
# Requirement already satisfied: jupyterlab-pygments in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (0.1.2)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (0.8.4)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (0.5.13)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (1.5.0)
# Requirement already satisfied: tinycss2 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (1.2.1)
# Requirement already satisfied: pywinpty>=1.1.0 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from terminado>=0.8.3->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (2.0.10)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (21.2.0)
# Requirement already satisfied: anyio>=3.1.0 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (3.5.0)
# Requirement already satisfied: jupyter-events>=0.4.0 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (0.6.3)
# Requirement already satisfied: jupyter-server-terminals in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (0.4.4)
# Requirement already satisfied: websocket-client in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (0.58.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (1.15.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (2.4)
# Requirement already satisfied: webencodings in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from bleach->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (0.5.1)
# Requirement already satisfied: sniffio>=1.1 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from anyio>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (1.2.0)
# Requirement already satisfied: pycparser in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (2.21)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from jupyter-events>=0.4.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (2.0.7)
# Requirement already satisfied: pyyaml>=5.3 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from jupyter-events>=0.4.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (6.0)
# Requirement already satisfied: rfc3339-validator in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from jupyter-events>=0.4.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from jupyter-events>=0.4.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.6.5->pycaret) (0.1.1)
# Requirement already satisfied: fqdn in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (1.5.1)
# Requirement already satisfied: isoduration in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (2.4)
# Requirement already satisfied: uri-template in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (1.3.0)
# Requirement already satisfied: webcolors>=1.11 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (1.13)
# Requirement already satisfied: arrow>=0.15.0 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from isoduration->jsonschema>=2.6->nbformat>=4.2.0->pycaret) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in c:\users\hp\anaconda3\envs\mypython1\lib\site-packages (from arrow>=0.15.0->isoduration->jsonschema>=2.6->nbformat>=4.2.0->pycaret) (2.8.19.14)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from pycaret.utils import version
version()
# Out:
# '3.2.0'

# %%
iris = pd.read_csv('Iris.csv')

# %%
iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
iris.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
iris.shape
# Out:
# (150, 6)

# %%
iris.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
iris.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
from pycaret.clustering import *

def modelfunction(clustering_algo='kmeans',transformation = False, normalize = False, pca = False,
      normalize_method = 'zscore',
      transformation_method = 'yeo-johnson',
      pca_method = 'linear', verbose=False):

  setup(data = iris, transformation = transformation, normalize = normalize, pca = pca,
      normalize_method = 'zscore',
      transformation_method = 'yeo-johnson',
      pca_method = 'linear', verbose=False)

  print("For Cluster = 3")
  x1 = create_model(clustering_algo, num_clusters = 3)
  metric1=pull()

  print("For Cluster = 4")
  x2 = create_model(clustering_algo, num_clusters = 4)
  metric2=pull()

  print("For Cluster = 5")
  x3 = create_model(clustering_algo, num_clusters = 5)
  metric3=pull()

  newtable=pd.concat([metric1,metric2,metric3],axis=0)
  newtable=newtable.T
  columnname=['Cluster1','Cluster2','Cluster3']
  newtable.columns=columnname
  print(newtable)
  return newtable

# %%
x=modelfunction()
print(x)
y=modelfunction(clustering_algo='hclust',normalize=True)
print(y)
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_0f2b7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0f2b7_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_0f2b7_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_0f2b7_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_0f2b7_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_0f2b7_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_0f2b7_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0f2b7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0f2b7_row0_col0" class="data row0 col0" >0.5820</td>
#       <td id="T_0f2b7_row0_col1" class="data row0 col1" >587.2801</td>
#       <td id="T_0f2b7_row0_col2" class="data row0 col2" >0.5015</td>
#       <td id="T_0f2b7_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_0f2b7_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_0f2b7_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 4
# <style type="text/css">
# </style>
# <table id="T_6dadf">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6dadf_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_6dadf_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_6dadf_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_6dadf_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_6dadf_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_6dadf_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6dadf_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6dadf_row0_col0" class="data row0 col0" >0.5561</td>
#       <td id="T_6dadf_row0_col1" class="data row0 col1" >721.0061</td>
#       <td id="T_6dadf_row0_col2" class="data row0 col2" >0.5084</td>
#       <td id="T_6dadf_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_6dadf_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_6dadf_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 5
# <style type="text/css">
# </style>
# <table id="T_28f42">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_28f42_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_28f42_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_28f42_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_28f42_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_28f42_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_28f42_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_28f42_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_28f42_row0_col0" class="data row0 col0" >0.5400</td>
#       <td id="T_28f42_row0_col1" class="data row0 col1" >855.1927</td>
#       <td id="T_28f42_row0_col2" class="data row0 col2" >0.5115</td>
#       <td id="T_28f42_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_28f42_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_28f42_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
#                    Cluster1  Cluster2  Cluster3
# Silhouette           0.5820    0.5561    0.5400
# Calinski-Harabasz  587.2801  721.0061  855.1927
# Davies-Bouldin       0.5015    0.5084    0.5115
# Homogeneity          0.0000    0.0000    0.0000
# Rand Index           0.0000    0.0000    0.0000
# Completeness         0.0000    0.0000    0.0000
#                    Cluster1  Cluster2  Cluster3
# Silhouette           0.5820    0.5561    0.5400
# Calinski-Harabasz  587.2801  721.0061  855.1927
# Davies-Bouldin       0.5015    0.5084    0.5115
# Homogeneity          0.0000    0.0000    0.0000
# Rand Index           0.0000    0.0000    0.0000
# Completeness         0.0000    0.0000    0.0000
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_ff5fc">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ff5fc_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_ff5fc_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_ff5fc_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_ff5fc_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_ff5fc_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_ff5fc_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ff5fc_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ff5fc_row0_col0" class="data row0 col0" >0.6486</td>
#       <td id="T_ff5fc_row0_col1" class="data row0 col1" >404.4205</td>
#       <td id="T_ff5fc_row0_col2" class="data row0 col2" >0.5379</td>
#       <td id="T_ff5fc_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_ff5fc_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_ff5fc_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 4
# <style type="text/css">
# </style>
# <table id="T_638ba">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_638ba_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_638ba_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_638ba_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_638ba_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_638ba_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_638ba_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_638ba_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_638ba_row0_col0" class="data row0 col0" >0.5450</td>
#       <td id="T_638ba_row0_col1" class="data row0 col1" >325.6777</td>
#       <td id="T_638ba_row0_col2" class="data row0 col2" >0.8195</td>
#       <td id="T_638ba_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_638ba_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_638ba_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 5
# <style type="text/css">
# </style>
# <table id="T_6dde6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6dde6_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_6dde6_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_6dde6_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_6dde6_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_6dde6_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_6dde6_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6dde6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6dde6_row0_col0" class="data row0 col0" >0.4472</td>
#       <td id="T_6dde6_row0_col1" class="data row0 col1" >298.4294</td>
#       <td id="T_6dde6_row0_col2" class="data row0 col2" >0.8917</td>
#       <td id="T_6dde6_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_6dde6_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_6dde6_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
#                    Cluster1  Cluster2  Cluster3
# Silhouette           0.6486    0.5450    0.4472
# Calinski-Harabasz  404.4205  325.6777  298.4294
# Davies-Bouldin       0.5379    0.8195    0.8917
# Homogeneity          0.0000    0.0000    0.0000
# Rand Index           0.0000    0.0000    0.0000
# Completeness         0.0000    0.0000    0.0000
#                    Cluster1  Cluster2  Cluster3
# Silhouette           0.6486    0.5450    0.4472
# Calinski-Harabasz  404.4205  325.6777  298.4294
# Davies-Bouldin       0.5379    0.8195    0.8917
# Homogeneity          0.0000    0.0000    0.0000
# Rand Index           0.0000    0.0000    0.0000
# Completeness         0.0000    0.0000    0.0000

# %%
table2=pd.concat([x,y],axis=1,keys=['No Data Preprocessing','Normalize'])
table2
# Out:
#                   No Data Preprocessing                     Normalize  \
#                                Cluster1  Cluster2  Cluster3  Cluster1
# Silhouette                       0.5820    0.5561    0.5400    0.6486
# Calinski-Harabasz              587.2801  721.0061  855.1927  404.4205
# Davies-Bouldin                   0.5015    0.5084    0.5115    0.5379
# Homogeneity                      0.0000    0.0000    0.0000    0.0000
# Rand Index                       0.0000    0.0000    0.0000    0.0000
# Completeness                     0.0000    0.0000    0.0000    0.0000
#
#
#                    Cluster2  Cluster3
# Silhouette           0.5450    0.4472
# Calinski-Harabasz  325.6777  298.4294
# Davies-Bouldin       0.8195    0.8917
# Homogeneity          0.0000    0.0000
# Rand Index           0.0000    0.0000
# Completeness         0.0000    0.0000

# %%
cluster_algo=['kmeans','birch','hclust']

list=[]

for i in range(len(cluster_algo)):

  newtable=pd.DataFrame()

  keys=['With No Data PreProcessing','Normalization','Transformation','PCA','Normalize+Tranforme','Normalize+Transform+PCA']

  # With No Data Preprocessing
  a=modelfunction(clustering_algo=cluster_algo[i])
  # With Normalization
  b=modelfunction(clustering_algo=cluster_algo[i],normalize=True)
  # With Transformation
  c=modelfunction(clustering_algo=cluster_algo[i],transformation = True)
  # wITH pca
  d=modelfunction(clustering_algo=cluster_algo[i],pca = True)
  # With N+T
  e=modelfunction(clustering_algo=cluster_algo[i],normalize=True,transformation = True)
  # with T+N+PCA
  f=modelfunction(clustering_algo=cluster_algo[i],normalize=True,transformation = True,pca=True)

  newtable=pd.concat([a,b,c,d,e,f],axis=1,keys=keys)
  list.insert(i,newtable)
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_70c41">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_70c41_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_70c41_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_70c41_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_70c41_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_70c41_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_70c41_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_70c41_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_70c41_row0_col0" class="data row0 col0" >0.5826</td>
#       <td id="T_70c41_row0_col1" class="data row0 col1" >588.1791</td>
#       <td id="T_70c41_row0_col2" class="data row0 col2" >0.5014</td>
#       <td id="T_70c41_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_70c41_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_70c41_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 4
# <style type="text/css">
# </style>
# <table id="T_67e95">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_67e95_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_67e95_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_67e95_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_67e95_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_67e95_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_67e95_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_67e95_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_67e95_row0_col0" class="data row0 col0" >0.5562</td>
#       <td id="T_67e95_row0_col1" class="data row0 col1" >721.8756</td>
#       <td id="T_67e95_row0_col2" class="data row0 col2" >0.5087</td>
#       <td id="T_67e95_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_67e95_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_67e95_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 5
# <style type="text/css">
# </style>
# <table id="T_bad83">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bad83_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_bad83_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_bad83_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_bad83_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_bad83_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_bad83_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bad83_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_bad83_row0_col0" class="data row0 col0" >0.5402</td>
#       <td id="T_bad83_row0_col1" class="data row0 col1" >855.1962</td>
#       <td id="T_bad83_row0_col2" class="data row0 col2" >0.5117</td>
#       <td id="T_bad83_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_bad83_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_bad83_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
#                    Cluster1  Cluster2  Cluster3
# Silhouette           0.5826    0.5562    0.5402
# Calinski-Harabasz  588.1791  721.8756  855.1962
# Davies-Bouldin       0.5014    0.5087    0.5117
# Homogeneity          0.0000    0.0000    0.0000
# Rand Index           0.0000    0.0000    0.0000
# Completeness         0.0000    0.0000    0.0000
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_98de2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_98de2_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_98de2_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_98de2_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_98de2_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_98de2_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_98de2_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_98de2_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_98de2_row0_col0" class="data row0 col0" >0.6486</td>
#       <td id="T_98de2_row0_col1" class="data row0 col1" >404.4205</td>
#       <td id="T_98de2_row0_col2" class="data row0 col2" >0.5379</td>
#       <td id="T_98de2_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_98de2_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_98de2_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 4
# <style type="text/css">
# </style>
# <table id="T_95a5c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_95a5c_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_95a5c_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_95a5c_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_95a5c_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_95a5c_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_95a5c_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_95a5c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_95a5c_row0_col0" class="data row0 col0" >0.5510</td>
#       <td id="T_95a5c_row0_col1" class="data row0 col1" >328.6301</td>
#       <td id="T_95a5c_row0_col2" class="data row0 col2" >0.7747</td>
#       <td id="T_95a5c_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_95a5c_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_95a5c_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 5
# <style type="text/css">
# </style>
# <table id="T_9fb3d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9fb3d_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_9fb3d_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_9fb3d_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_9fb3d_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_9fb3d_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_9fb3d_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9fb3d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9fb3d_row0_col0" class="data row0 col0" >0.4360</td>
#       <td id="T_9fb3d_row0_col1" class="data row0 col1" >303.0404</td>
#       <td id="T_9fb3d_row0_col2" class="data row0 col2" >0.9012</td>
#       <td id="T_9fb3d_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_9fb3d_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_9fb3d_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
#                    Cluster1  Cluster2  Cluster3
# Silhouette           0.6486    0.5510    0.4360
# Calinski-Harabasz  404.4205  328.6301  303.0404
# Davies-Bouldin       0.5379    0.7747    0.9012
# Homogeneity          0.0000    0.0000    0.0000
# Rand Index           0.0000    0.0000    0.0000
# Completeness         0.0000    0.0000    0.0000
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_994d1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_994d1_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_994d1_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_994d1_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_994d1_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_994d1_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_994d1_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_994d1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_994d1_row0_col0" class="data row0 col0" >0.5685</td>
#       <td id="T_994d1_row0_col1" class="data row0 col1" >538.3096</td>
#       <td id="T_994d1_row0_col2" class="data row0 col2" >0.5198</td>
#       <td id="T_994d1_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_994d1_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_994d1_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 4
# <style type="text/css">
# </style>
# <table id="T_295e1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_295e1_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_295e1_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_295e1_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_295e1_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_295e1_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_295e1_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_295e1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_295e1_row0_col0" class="data row0 col0" >0.5396</td>
#       <td id="T_295e1_row0_col1" class="data row0 col1" >639.1933</td>
#       <td id="T_295e1_row0_col2" class="data row0 col2" >0.5423</td>
#       <td id="T_295e1_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_295e1_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_295e1_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 5
# <style type="text/css">
# </style>
# <table id="T_55e49">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_55e49_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_55e49_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_55e49_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_55e49_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_55e49_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_55e49_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_55e49_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_55e49_row0_col0" class="data row0 col0" >0.5366</td>
#       <td id="T_55e49_row0_col1" class="data row0 col1" >779.3104</td>
#       <td id="T_55e49_row0_col2" class="data row0 col2" >0.5354</td>
#       <td id="T_55e49_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_55e49_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_55e49_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
#                    Cluster1  Cluster2  Cluster3
# Silhouette           0.5685    0.5396    0.5366
# Calinski-Harabasz  538.3096  639.1933  779.3104
# Davies-Bouldin       0.5198    0.5423    0.5354
# Homogeneity          0.0000    0.0000    0.0000
# Rand Index           0.0000    0.0000    0.0000
# Completeness         0.0000    0.0000    0.0000
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_01f2f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_01f2f_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_01f2f_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_01f2f_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_01f2f_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_01f2f_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_01f2f_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_01f2f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_01f2f_row0_col0" class="data row0 col0" >0.5826</td>
#       <td id="T_01f2f_row0_col1" class="data row0 col1" >588.1791</td>
#       <td id="T_01f2f_row0_col2" class="data row0 col2" >0.5014</td>
#       <td id="T_01f2f_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_01f2f_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_01f2f_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 4
# <style type="text/css">
# </style>
# <table id="T_06e77">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_06e77_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_06e77_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_06e77_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_06e77_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_06e77_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_06e77_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_06e77_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_06e77_row0_col0" class="data row0 col0" >0.5563</td>
#       <td id="T_06e77_row0_col1" class="data row0 col1" >720.3951</td>
#       <td id="T_06e77_row0_col2" class="data row0 col2" >0.5081</td>
#       <td id="T_06e77_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_06e77_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_06e77_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 5
# <style type="text/css">
# </style>
# <table id="T_e96f4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e96f4_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_e96f4_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_e96f4_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_e96f4_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_e96f4_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_e96f4_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e96f4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e96f4_row0_col0" class="data row0 col0" >0.5405</td>
#       <td id="T_e96f4_row0_col1" class="data row0 col1" >853.7834</td>
#       <td id="T_e96f4_row0_col2" class="data row0 col2" >0.5115</td>
#       <td id="T_e96f4_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_e96f4_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_e96f4_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
#                    Cluster1  Cluster2  Cluster3
# Silhouette           0.5826    0.5563    0.5405
# Calinski-Harabasz  588.1791  720.3951  853.7834
# Davies-Bouldin       0.5014    0.5081    0.5115
# Homogeneity          0.0000    0.0000    0.0000
# Rand Index           0.0000    0.0000    0.0000
# Completeness         0.0000    0.0000    0.0000
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_aae7b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_aae7b_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_aae7b_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_aae7b_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_aae7b_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_aae7b_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_aae7b_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_aae7b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_aae7b_row0_col0" class="data row0 col0" >0.6459</td>
#       <td id="T_aae7b_row0_col1" class="data row0 col1" >404.4590</td>
#       <td id="T_aae7b_row0_col2" class="data row0 col2" >0.5416</td>
#       <td id="T_aae7b_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_aae7b_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_aae7b_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 4
# <style type="text/css">
# </style>
# <table id="T_610eb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_610eb_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_610eb_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_610eb_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_610eb_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_610eb_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_610eb_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_610eb_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_610eb_row0_col0" class="data row0 col0" >0.5570</td>
#       <td id="T_610eb_row0_col1" class="data row0 col1" >329.1376</td>
#       <td id="T_610eb_row0_col2" class="data row0 col2" >0.7066</td>
#       <td id="T_610eb_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_610eb_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_610eb_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 5
# <style type="text/css">
# </style>
# <table id="T_63fe4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_63fe4_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_63fe4_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_63fe4_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_63fe4_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_63fe4_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_63fe4_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_63fe4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_63fe4_row0_col0" class="data row0 col0" >0.4748</td>
#       <td id="T_63fe4_row0_col1" class="data row0 col1" >305.9889</td>
#       <td id="T_63fe4_row0_col2" class="data row0 col2" >0.8803</td>
#       <td id="T_63fe4_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_63fe4_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_63fe4_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
#                    Cluster1  Cluster2  Cluster3
# Silhouette           0.6459    0.5570    0.4748
# Calinski-Harabasz  404.4590  329.1376  305.9889
# Davies-Bouldin       0.5416    0.7066    0.8803
# Homogeneity          0.0000    0.0000    0.0000
# Rand Index           0.0000    0.0000    0.0000
# Completeness         0.0000    0.0000    0.0000
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_c5ef4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c5ef4_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_c5ef4_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_c5ef4_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_c5ef4_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_c5ef4_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_c5ef4_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c5ef4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c5ef4_row0_col0" class="data row0 col0" >0.6459</td>
#       <td id="T_c5ef4_row0_col1" class="data row0 col1" >404.4590</td>
#       <td id="T_c5ef4_row0_col2" class="data row0 col2" >0.5416</td>
#       <td id="T_c5ef4_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_c5ef4_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_c5ef4_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 4
# <style type="text/css">
# </style>
# <table id="T_6a5b9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6a5b9_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_6a5b9_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_6a5b9_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_6a5b9_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_6a5b9_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_6a5b9_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6a5b9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6a5b9_row0_col0" class="data row0 col0" >0.5570</td>
#       <td id="T_6a5b9_row0_col1" class="data row0 col1" >329.1376</td>
#       <td id="T_6a5b9_row0_col2" class="data row0 col2" >0.7066</td>
#       <td id="T_6a5b9_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_6a5b9_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_6a5b9_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 5
# <style type="text/css">
# </style>
# <table id="T_156d9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_156d9_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_156d9_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_156d9_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_156d9_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_156d9_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_156d9_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_156d9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_156d9_row0_col0" class="data row0 col0" >0.4748</td>
#       <td id="T_156d9_row0_col1" class="data row0 col1" >305.9889</td>
#       <td id="T_156d9_row0_col2" class="data row0 col2" >0.8803</td>
#       <td id="T_156d9_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_156d9_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_156d9_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
#                    Cluster1  Cluster2  Cluster3
# Silhouette           0.6459    0.5570    0.4748
# Calinski-Harabasz  404.4590  329.1376  305.9889
# Davies-Bouldin       0.5416    0.7066    0.8803
# Homogeneity          0.0000    0.0000    0.0000
# Rand Index           0.0000    0.0000    0.0000
# Completeness         0.0000    0.0000    0.0000
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_d2aa5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d2aa5_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_d2aa5_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_d2aa5_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_d2aa5_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_d2aa5_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_d2aa5_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d2aa5_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d2aa5_row0_col0" class="data row0 col0" >0.5540</td>
#       <td id="T_d2aa5_row0_col1" class="data row0 col1" >527.9268</td>
#       <td id="T_d2aa5_row0_col2" class="data row0 col2" >0.5023</td>
#       <td id="T_d2aa5_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_d2aa5_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_d2aa5_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 4
# <style type="text/css">
# </style>
# <table id="T_f7a76">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f7a76_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_f7a76_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_f7a76_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_f7a76_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_f7a76_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_f7a76_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f7a76_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f7a76_row0_col0" class="data row0 col0" >0.5293</td>
#       <td id="T_f7a76_row0_col1" class="data row0 col1" >608.4987</td>
#       <td id="T_f7a76_row0_col2" class="data row0 col2" >0.5127</td>
#       <td id="T_f7a76_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_f7a76_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_f7a76_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 5
# <style type="text/css">
# </style>
# <table id="T_1403b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1403b_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_1403b_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_1403b_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_1403b_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_1403b_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_1403b_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1403b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1403b_row0_col0" class="data row0 col0" >0.4997</td>
#       <td id="T_1403b_row0_col1" class="data row0 col1" >739.1396</td>
#       <td id="T_1403b_row0_col2" class="data row0 col2" >0.5133</td>
#       <td id="T_1403b_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_1403b_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_1403b_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
#                    Cluster1  Cluster2  Cluster3
# Silhouette           0.5540    0.5293    0.4997
# Calinski-Harabasz  527.9268  608.4987  739.1396
# Davies-Bouldin       0.5023    0.5127    0.5133
# Homogeneity          0.0000    0.0000    0.0000
# Rand Index           0.0000    0.0000    0.0000
# Completeness         0.0000    0.0000    0.0000
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_b8f2c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b8f2c_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_b8f2c_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_b8f2c_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_b8f2c_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_b8f2c_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_b8f2c_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b8f2c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b8f2c_row0_col0" class="data row0 col0" >0.6486</td>
#       <td id="T_b8f2c_row0_col1" class="data row0 col1" >404.4205</td>
#       <td id="T_b8f2c_row0_col2" class="data row0 col2" >0.5379</td>
#       <td id="T_b8f2c_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_b8f2c_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_b8f2c_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 4
# <style type="text/css">
# </style>
# <table id="T_863f7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_863f7_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_863f7_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_863f7_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_863f7_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_863f7_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_863f7_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_863f7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_863f7_row0_col0" class="data row0 col0" >0.5491</td>
#       <td id="T_863f7_row0_col1" class="data row0 col1" >327.9265</td>
#       <td id="T_863f7_row0_col2" class="data row0 col2" >0.7916</td>
#       <td id="T_863f7_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_863f7_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_863f7_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 5
# <style type="text/css">
# </style>
# <table id="T_e1d27">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e1d27_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_e1d27_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_e1d27_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_e1d27_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_e1d27_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_e1d27_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e1d27_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e1d27_row0_col0" class="data row0 col0" >0.4430</td>
#       <td id="T_e1d27_row0_col1" class="data row0 col1" >300.2124</td>
#       <td id="T_e1d27_row0_col2" class="data row0 col2" >0.8918</td>
#       <td id="T_e1d27_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_e1d27_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_e1d27_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
#                    Cluster1  Cluster2  Cluster3
# Silhouette           0.6486    0.5491    0.4430
# Calinski-Harabasz  404.4205  327.9265  300.2124
# Davies-Bouldin       0.5379    0.7916    0.8918
# Homogeneity          0.0000    0.0000    0.0000
# Rand Index           0.0000    0.0000    0.0000
# Completeness         0.0000    0.0000    0.0000
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_c55e0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c55e0_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_c55e0_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_c55e0_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_c55e0_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_c55e0_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_c55e0_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c55e0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c55e0_row0_col0" class="data row0 col0" >0.5746</td>
#       <td id="T_c55e0_row0_col1" class="data row0 col1" >523.7344</td>
#       <td id="T_c55e0_row0_col2" class="data row0 col2" >0.5134</td>
#       <td id="T_c55e0_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_c55e0_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_c55e0_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 4
# <style type="text/css">
# </style>
# <table id="T_704a9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_704a9_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_704a9_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_704a9_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_704a9_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_704a9_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_704a9_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_704a9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_704a9_row0_col0" class="data row0 col0" >0.5539</td>
#       <td id="T_704a9_row0_col1" class="data row0 col1" >585.0348</td>
#       <td id="T_704a9_row0_col2" class="data row0 col2" >0.5093</td>
#       <td id="T_704a9_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_704a9_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_704a9_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 5
# <style type="text/css">
# </style>
# <table id="T_e5ccc">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e5ccc_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_e5ccc_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_e5ccc_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_e5ccc_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_e5ccc_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_e5ccc_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e5ccc_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e5ccc_row0_col0" class="data row0 col0" >0.5160</td>
#       <td id="T_e5ccc_row0_col1" class="data row0 col1" >642.3755</td>
#       <td id="T_e5ccc_row0_col2" class="data row0 col2" >0.5178</td>
#       <td id="T_e5ccc_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_e5ccc_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_e5ccc_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
#                    Cluster1  Cluster2  Cluster3
# Silhouette           0.5746    0.5539    0.5160
# Calinski-Harabasz  523.7344  585.0348  642.3755
# Davies-Bouldin       0.5134    0.5093    0.5178
# Homogeneity          0.0000    0.0000    0.0000
# Rand Index           0.0000    0.0000    0.0000
# Completeness         0.0000    0.0000    0.0000
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_26a67">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_26a67_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_26a67_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_26a67_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_26a67_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_26a67_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_26a67_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_26a67_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_26a67_row0_col0" class="data row0 col0" >0.5540</td>
#       <td id="T_26a67_row0_col1" class="data row0 col1" >527.9268</td>
#       <td id="T_26a67_row0_col2" class="data row0 col2" >0.5023</td>
#       <td id="T_26a67_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_26a67_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_26a67_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 4
# <style type="text/css">
# </style>
# <table id="T_262d5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_262d5_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_262d5_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_262d5_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_262d5_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_262d5_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_262d5_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_262d5_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_262d5_row0_col0" class="data row0 col0" >0.5293</td>
#       <td id="T_262d5_row0_col1" class="data row0 col1" >608.4987</td>
#       <td id="T_262d5_row0_col2" class="data row0 col2" >0.5127</td>
#       <td id="T_262d5_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_262d5_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_262d5_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 5
# <style type="text/css">
# </style>
# <table id="T_144d5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_144d5_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_144d5_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_144d5_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_144d5_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_144d5_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_144d5_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_144d5_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_144d5_row0_col0" class="data row0 col0" >0.4997</td>
#       <td id="T_144d5_row0_col1" class="data row0 col1" >739.1396</td>
#       <td id="T_144d5_row0_col2" class="data row0 col2" >0.5133</td>
#       <td id="T_144d5_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_144d5_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_144d5_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
#                    Cluster1  Cluster2  Cluster3
# Silhouette           0.5540    0.5293    0.4997
# Calinski-Harabasz  527.9268  608.4987  739.1396
# Davies-Bouldin       0.5023    0.5127    0.5133
# Homogeneity          0.0000    0.0000    0.0000
# Rand Index           0.0000    0.0000    0.0000
# Completeness         0.0000    0.0000    0.0000
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_0e11f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0e11f_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_0e11f_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_0e11f_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_0e11f_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_0e11f_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_0e11f_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0e11f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0e11f_row0_col0" class="data row0 col0" >0.6459</td>
#       <td id="T_0e11f_row0_col1" class="data row0 col1" >404.4590</td>
#       <td id="T_0e11f_row0_col2" class="data row0 col2" >0.5416</td>
#       <td id="T_0e11f_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_0e11f_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_0e11f_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 4
# <style type="text/css">
# </style>
# <table id="T_736a6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_736a6_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_736a6_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_736a6_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_736a6_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_736a6_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_736a6_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_736a6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_736a6_row0_col0" class="data row0 col0" >0.5430</td>
#       <td id="T_736a6_row0_col1" class="data row0 col1" >321.6586</td>
#       <td id="T_736a6_row0_col2" class="data row0 col2" >0.7921</td>
#       <td id="T_736a6_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_736a6_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_736a6_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 5
# <style type="text/css">
# </style>
# <table id="T_1ba1c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1ba1c_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_1ba1c_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_1ba1c_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_1ba1c_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_1ba1c_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_1ba1c_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1ba1c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1ba1c_row0_col0" class="data row0 col0" >0.4257</td>
#       <td id="T_1ba1c_row0_col1" class="data row0 col1" >291.5082</td>
#       <td id="T_1ba1c_row0_col2" class="data row0 col2" >0.9464</td>
#       <td id="T_1ba1c_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_1ba1c_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_1ba1c_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
#                    Cluster1  Cluster2  Cluster3
# Silhouette           0.6459    0.5430    0.4257
# Calinski-Harabasz  404.4590  321.6586  291.5082
# Davies-Bouldin       0.5416    0.7921    0.9464
# Homogeneity          0.0000    0.0000    0.0000
# Rand Index           0.0000    0.0000    0.0000
# Completeness         0.0000    0.0000    0.0000
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_23016">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_23016_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_23016_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_23016_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_23016_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_23016_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_23016_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_23016_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_23016_row0_col0" class="data row0 col0" >0.6459</td>
#       <td id="T_23016_row0_col1" class="data row0 col1" >404.4590</td>
#       <td id="T_23016_row0_col2" class="data row0 col2" >0.5416</td>
#       <td id="T_23016_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_23016_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_23016_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 4
# <style type="text/css">
# </style>
# <table id="T_f8cf4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f8cf4_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_f8cf4_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_f8cf4_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_f8cf4_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_f8cf4_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_f8cf4_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f8cf4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f8cf4_row0_col0" class="data row0 col0" >0.5430</td>
#       <td id="T_f8cf4_row0_col1" class="data row0 col1" >321.6586</td>
#       <td id="T_f8cf4_row0_col2" class="data row0 col2" >0.7921</td>
#       <td id="T_f8cf4_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_f8cf4_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_f8cf4_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 5
# <style type="text/css">
# </style>
# <table id="T_94163">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_94163_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_94163_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_94163_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_94163_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_94163_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_94163_level0_col5" class="col_heading level0 col5" >Completeness</th>
# ...
#       <th id="T_48d5e_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_48d5e_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_48d5e_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_48d5e_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_48d5e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_48d5e_row0_col0" class="data row0 col0" >0.5531</td>
#       <td id="T_48d5e_row0_col1" class="data row0 col1" >493.7557</td>
#       <td id="T_48d5e_row0_col2" class="data row0 col2" >0.5203</td>
#       <td id="T_48d5e_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_48d5e_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_48d5e_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 4
# <style type="text/css">
# </style>
# <table id="T_cf051">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cf051_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_cf051_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_cf051_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_cf051_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_cf051_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_cf051_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cf051_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_cf051_row0_col0" class="data row0 col0" >0.5233</td>
#       <td id="T_cf051_row0_col1" class="data row0 col1" >586.1355</td>
#       <td id="T_cf051_row0_col2" class="data row0 col2" >0.5589</td>
#       <td id="T_cf051_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_cf051_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_cf051_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 5
# <style type="text/css">
# </style>
# <table id="T_458df">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_458df_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_458df_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_458df_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_458df_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_458df_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_458df_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_458df_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_458df_row0_col0" class="data row0 col0" >0.5122</td>
#       <td id="T_458df_row0_col1" class="data row0 col1" >631.4806</td>
#       <td id="T_458df_row0_col2" class="data row0 col2" >0.5498</td>
#       <td id="T_458df_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_458df_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_458df_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
#                    Cluster1  Cluster2  Cluster3
# Silhouette           0.5531    0.5233    0.5122
# Calinski-Harabasz  493.7557  586.1355  631.4806
# Davies-Bouldin       0.5203    0.5589    0.5498
# Homogeneity          0.0000    0.0000    0.0000
# Rand Index           0.0000    0.0000    0.0000
# Completeness         0.0000    0.0000    0.0000
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_9d93d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9d93d_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_9d93d_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_9d93d_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_9d93d_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_9d93d_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_9d93d_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9d93d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9d93d_row0_col0" class="data row0 col0" >0.5540</td>
#       <td id="T_9d93d_row0_col1" class="data row0 col1" >527.9268</td>
#       <td id="T_9d93d_row0_col2" class="data row0 col2" >0.5023</td>
#       <td id="T_9d93d_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_9d93d_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_9d93d_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 4
# <style type="text/css">
# </style>
# <table id="T_5ec60">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5ec60_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_5ec60_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_5ec60_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_5ec60_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_5ec60_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_5ec60_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5ec60_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5ec60_row0_col0" class="data row0 col0" >0.5293</td>
#       <td id="T_5ec60_row0_col1" class="data row0 col1" >608.4987</td>
#       <td id="T_5ec60_row0_col2" class="data row0 col2" >0.5127</td>
#       <td id="T_5ec60_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_5ec60_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_5ec60_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 5
# <style type="text/css">
# </style>
# <table id="T_9bf31">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9bf31_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_9bf31_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_9bf31_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_9bf31_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_9bf31_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_9bf31_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9bf31_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9bf31_row0_col0" class="data row0 col0" >0.4997</td>
#       <td id="T_9bf31_row0_col1" class="data row0 col1" >739.1396</td>
#       <td id="T_9bf31_row0_col2" class="data row0 col2" >0.5133</td>
#       <td id="T_9bf31_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_9bf31_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_9bf31_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
#                    Cluster1  Cluster2  Cluster3
# Silhouette           0.5540    0.5293    0.4997
# Calinski-Harabasz  527.9268  608.4987  739.1396
# Davies-Bouldin       0.5023    0.5127    0.5133
# Homogeneity          0.0000    0.0000    0.0000
# Rand Index           0.0000    0.0000    0.0000
# Completeness         0.0000    0.0000    0.0000
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_18a25">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_18a25_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_18a25_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_18a25_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_18a25_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_18a25_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_18a25_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_18a25_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_18a25_row0_col0" class="data row0 col0" >0.6459</td>
#       <td id="T_18a25_row0_col1" class="data row0 col1" >404.4590</td>
#       <td id="T_18a25_row0_col2" class="data row0 col2" >0.5416</td>
#       <td id="T_18a25_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_18a25_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_18a25_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 4
# <style type="text/css">
# </style>
# <table id="T_da69a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_da69a_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_da69a_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_da69a_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_da69a_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_da69a_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_da69a_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_da69a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_da69a_row0_col0" class="data row0 col0" >0.5492</td>
#       <td id="T_da69a_row0_col1" class="data row0 col1" >324.7465</td>
#       <td id="T_da69a_row0_col2" class="data row0 col2" >0.7331</td>
#       <td id="T_da69a_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_da69a_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_da69a_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 5
# <style type="text/css">
# </style>
# <table id="T_36b34">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_36b34_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_36b34_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_36b34_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_36b34_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_36b34_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_36b34_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_36b34_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_36b34_row0_col0" class="data row0 col0" >0.4542</td>
#       <td id="T_36b34_row0_col1" class="data row0 col1" >296.6966</td>
#       <td id="T_36b34_row0_col2" class="data row0 col2" >0.9347</td>
#       <td id="T_36b34_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_36b34_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_36b34_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
#                    Cluster1  Cluster2  Cluster3
# Silhouette           0.6459    0.5492    0.4542
# Calinski-Harabasz  404.4590  324.7465  296.6966
# Davies-Bouldin       0.5416    0.7331    0.9347
# Homogeneity          0.0000    0.0000    0.0000
# Rand Index           0.0000    0.0000    0.0000
# Completeness         0.0000    0.0000    0.0000
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_f463d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f463d_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_f463d_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_f463d_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_f463d_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_f463d_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_f463d_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f463d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f463d_row0_col0" class="data row0 col0" >0.6459</td>
#       <td id="T_f463d_row0_col1" class="data row0 col1" >404.4590</td>
#       <td id="T_f463d_row0_col2" class="data row0 col2" >0.5416</td>
#       <td id="T_f463d_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_f463d_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_f463d_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 4
# <style type="text/css">
# </style>
# <table id="T_abbb4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_abbb4_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_abbb4_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_abbb4_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_abbb4_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_abbb4_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_abbb4_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_abbb4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_abbb4_row0_col0" class="data row0 col0" >0.5492</td>
#       <td id="T_abbb4_row0_col1" class="data row0 col1" >324.7465</td>
#       <td id="T_abbb4_row0_col2" class="data row0 col2" >0.7331</td>
#       <td id="T_abbb4_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_abbb4_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_abbb4_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
# For Cluster = 5
# <style type="text/css">
# </style>
# <table id="T_bdb9a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bdb9a_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_bdb9a_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_bdb9a_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_bdb9a_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_bdb9a_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_bdb9a_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bdb9a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_bdb9a_row0_col0" class="data row0 col0" >0.4542</td>
#       <td id="T_bdb9a_row0_col1" class="data row0 col1" >296.6966</td>
#       <td id="T_bdb9a_row0_col2" class="data row0 col2" >0.9347</td>
#       <td id="T_bdb9a_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_bdb9a_row0_col4" class="data row0 col4" >0</td>
#       <td id="T_bdb9a_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
# Processing:   0%|          | 0/3 [00:00<?, ?it/s]
#                    Cluster1  Cluster2  Cluster3
# Silhouette           0.6459    0.5492    0.4542
# Calinski-Harabasz  404.4590  324.7465  296.6966
# Davies-Bouldin       0.5416    0.7331    0.9347
# Homogeneity          0.0000    0.0000    0.0000
# Rand Index           0.0000    0.0000    0.0000
# Completeness         0.0000    0.0000    0.0000

# %%
# !pip install openpyxl
Cluster_names=['Kmeans Clustering','Birch Clustering','Hierarchial Clustering']
i=0


with pd.ExcelWriter('clustering_final_output.xlsx') as writer:
  for i, df in enumerate(list):
      print(f"Clustering Algo {i+1}:")
      print(Cluster_names[i])
      print()
      df.to_excel(writer, sheet_name=Cluster_names[i])

print()
print("Result of each Clustering Algorithm on Separate Sheet")
# Out:
# Collecting openpyxl
#   Downloading openpyxl-3.1.2-py2.py3-none-any.whl (249 kB)
#                                               0.0/250.0 kB ? eta -:--:--
#                                               0.0/250.0 kB ? eta -:--:--
#      ---------                               61.4/250.0 kB 3.2 MB/s eta 0:00:01
#      -------------------------------------- 250.0/250.0 kB 5.1 MB/s eta 0:00:00
# Collecting et-xmlfile (from openpyxl)
#   Downloading et_xmlfile-1.1.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: et-xmlfile, openpyxl
# Successfully installed et-xmlfile-1.1.0 openpyxl-3.1.2
# Clustering Algo 1:
# Kmeans Clustering
#
# Clustering Algo 2:
# Birch Clustering
#
# Clustering Algo 3:
# Hierarchial Clustering
#
#
# Result of each Clustering Algorithm on Separate Sheet
